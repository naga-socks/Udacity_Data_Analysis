# %%
import wptools

# %%
# test scrip example
page = wptools.page('Mahatma_Gandhi').get()
# Out:
# en.wikipedia.org (query) Mahatma_Gandhi
# en.wikipedia.org (query) Mahatma Gandhi (&plcontinue=19379|0|Fran...
# en.wikipedia.org (query) Mahatma Gandhi (&plcontinue=19379|0|Maha...
# en.wikipedia.org (query) Mahatma Gandhi (&plcontinue=19379|0|Sidd...
# en.wikipedia.org (parse) 19379
# www.wikidata.org (wikidata) Q1001
# www.wikidata.org (labels) P3219|P1375|P7029|P1417|P6394|P1149|P17...
# www.wikidata.org (labels) Q1390715|P3232|P1225|P3430|P6683|P569|P...
# www.wikidata.org (labels) Q12937862|P1559|Q82955|P1006|Q11735530|...
# www.wikidata.org (labels) Q84|Q1210083|Q46002746|Q258|P6404|P8189...
# www.wikidata.org (labels) P8851|P1890|P910|Q3242115|P2959|P5375|P...
# www.wikidata.org (labels) P5587|P4862|P734|Q808967|P691|P3417|P30...
# en.wikipedia.org (restbase) /page/summary/Mahatma_Gandhi
# en.wikipedia.org (imageinfo) File:Mahatma-Gandhi, studio, 1931.jp...
# Mahatma Gandhi (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(12)> Mahatma Mohandas Karamchand Gandhi, M. K. Ga...
#   assessments: <dict(10)> Biography, Politics, Alternative Views, ...
#   claims: <dict(213)> P27, P19, P20, P26, P157, P103, P69, P140, P...
#   description: 20th-century Indian nationalist leader
#   exhtml: <str(412)> <p><b>Mohandas Karamchand Gandhi</b> was an I...
#   exrest: <str(391)> Mohandas Karamchand Gandhi was an Indian lawy...
#   extext: <str(3464)> **Mohandas Karamchand Gandhi** (; 2 October ...
#   extract: <str(3617)> <p class="mw-empty-elt"></p><p><b>Mohandas ...
#   image: <list(14)> {'kind': 'query-pageimage', 'file': 'File:Maha...
#   infobox: <dict(26)> honorific_prefix, name, image, caption, citi...
#   iwlinks: <list(7)> https://commons.wikimedia.org/wiki/Mohandas_K...
#   label: Mahatma Gandhi
#   labels: <dict(289)> P3219, P1375, P7029, P1417, P6394, P1149, P1...
#   length: 292,218
#   links: <list(1869)> 10, Janpath, 120461 Gandhi, 14th Dalai Lama,...
#   modified: <dict(2)> page, wikidata
#   pageid: 19379
#   parsetree: <str(366372)> <root><template><title>Short descriptio...
#   random: FC Slutsk
#   redirects: <list(52)> {'pageid': 55342, 'ns': 0, 'title': 'Mahat...
#   requests: <list(14)> query, query, query, query, parse, wikidata...
#   title: Mahatma_Gandhi
#   url: https://en.wikipedia.org/wiki/Mahatma_Gandhi
#   url_raw: https://en.wikipedia.org/wiki/Mahatma_Gandhi?action=raw
#   watchers: 2,263
#   what: human
#   wikibase: Q1001
#   wikidata: <dict(213)> country of citizenship (P27), place of bir...
#   wikidata_pageid: 1330
#   wikidata_url: https://www.wikidata.org/wiki/Q1001
#   wikitext: <str(290653)> {{Short description|20th-century Indian ...
# }

# %%
page.data['image']
# Out:
# [{'kind': 'query-pageimage',
#   'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'orig': 'Mahatma-Gandhi,_studio,_1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'query-thumbnail',
#   'width': 192,
#   'height': 240,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg/192px-Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': 'Mahatma-Gandhi%2C_studio%2C_1931.jpg'},
#  {'kind': 'query-pageimage',
#   'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'orig': 'Mahatma-Gandhi,_studio,_1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'query-thumbnail',
#   'width': 192,
#   'height': 240,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg/192px-Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': 'Mahatma-Gandhi%2C_studio%2C_1931.jpg'},
#  {'kind': 'query-pageimage',
#   'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'orig': 'Mahatma-Gandhi,_studio,_1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'query-thumbnail',
#   'width': 192,
#   'height': 240,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg/192px-Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': 'Mahatma-Gandhi%2C_studio%2C_1931.jpg'},
#  {'kind': 'query-pageimage',
#   'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'orig': 'Mahatma-Gandhi,_studio,_1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'query-thumbnail',
#   'width': 192,
#   'height': 240,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg/192px-Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': 'Mahatma-Gandhi%2C_studio%2C_1931.jpg'},
#  {'kind': 'parse-image',
#   'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'orig': 'Mahatma-Gandhi, studio, 1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'file': 'File:Portrait Gandhi.jpg',
#   'kind': 'wikidata-image',
#   'orig': 'Portrait Gandhi.jpg',
#   'timestamp': '2007-07-08T10:21:04Z',
#   'size': 2951123,
#   'width': 2024,
#   'height': 3040,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/d/d1/Portrait_Gandhi.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Portrait_Gandhi.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=2369294',
#   'title': 'File:Portrait Gandhi.jpg',
#   'metadata': {'DateTime': {'value': '2007-07-08 10:21:04',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Portrait Gandhi',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': '1930s portrait photographs of men|20th-century portrait photographs of men at bust length|Files uploaded by Yann Forget|Flickr images missing SDC creator|Flickr images missing SDC inception|Flickr images missing SDC source of file|Flickr images reviewed by FlickreviewR|Images with extracted images|Mohandas K. Gandhi in the 1930s|PD-1996|PD India|People wearing round glasses|Portrait photographs of Mohandas K. Gandhi|Template Unknown (author)',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': '', 'source': 'commons-categories', 'hidden': ''},
#    'ImageDescription': {'value': 'Mohandas K. Gandhi',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': 'probably late 1930s',
#     'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="https://www.flickr.com/photos/55638925@N00/255569844/">https://www.flickr.com/photos/55638925@N00/255569844/</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Unknown author<span style="display: none;">Unknown author</span>',
#     'source': 'commons-desc-page'},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'file': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'kind': 'wikidata-image',
#   'orig': 'Mahatma-Gandhi, studio, 1931.jpg',
#   'timestamp': '2019-02-26T13:14:24Z',
#   'size': 3250029,
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Mahatma-Gandhi,_studio,_1931.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=76882768',
#   'title': 'File:Mahatma-Gandhi, studio, 1931.jpg',
#   'metadata': {'DateTime': {'value': '2019-02-26 13:14:24',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Mahatma-Gandhi, studio, 1931',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'Files uploaded by Yann Forget|Mohandas K. Gandhi in 1931|Mohandas K. Gandhi in England|PD-1996|PD-UK',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': 'valued',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'ImageDescription': {'value': 'Studio photograph of Mohandas K. Gandhi, London, 1931.',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '1931', 'source': 'commons-desc-page'},
#    'Credit': {'value': '<a rel="nofollow" class="external free" href="http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg">http://philogalichet.fr/wp-content/uploads/2019/01/Gandhi_Photo-Alamy.jpg</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': 'Elliott &amp; Fry (see <a rel="nofollow" class="external autonumber" href="https://www.gettyimages.in/detail/news-photo/indian-nationalist-leader-mohandas-karamchand-gandhi-news-photo/2668873">[1]</a>)',
#     'source': 'commons-desc-page'},
#    'Permission': {'value': 'Copyright expired 50 years after publication. It was most probably published in USA at the time.',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'file': 'File:Gandhi 1944.jpg',
#   'kind': 'wikidata-image',
#   'orig': 'Gandhi 1944.jpg',
#   'timestamp': '2007-01-30T21:34:33Z',
#   'size': 76781,
#   'width': 368,
#   'height': 480,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/0/03/Gandhi_1944.jpg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:Gandhi_1944.jpg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=1611809',
#   'title': 'File:Gandhi 1944.jpg',
#   'metadata': {'DateTime': {'value': '2007-01-30 21:34:33',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'Gandhi 1944',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': '1944 portrait photographs of men|20th-century portrait photographs of men at bust length|Files with no machine-readable author|Files with no machine-readable source|Media missing infobox template|Mohandas K. Gandhi in 1944|Mohandas K. Gandhi in India|PD India|Portrait photographs of Mohandas K. Gandhi',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': '', 'source': 'commons-categories', 'hidden': ''},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '', 'source': 'commons-desc-page', 'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'restbase-original',
#   'width': 2620,
#   'height': 3270,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': 'Mahatma-Gandhi%2C_studio%2C_1931.jpg'},
#  {'kind': 'restbase-thumb',
#   'width': 256,
#   'height': 320,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Mahatma-Gandhi%2C_studio%2C_1931.jpg/256px-Mahatma-Gandhi%2C_studio%2C_1931.jpg',
#   'file': 'File:256px-Mahatma-Gandhi%2C studio%2C 1931.jpg',
#   'orig': '256px-Mahatma-Gandhi%2C_studio%2C_1931.jpg'}]

# %%
# Your code here: get the E.T. page object
# This cell make take a few seconds to run
page = wptools.page('E.T._the_Extra-Terrestrial').get()
# Out:
# en.wikipedia.org (query) E.T._the_Extra-Terrestrial
# en.wikipedia.org (query) E.T. the Extra-Terrestrial (&plcontinue=...
# en.wikipedia.org (parse) 73441
# www.wikidata.org (wikidata) Q11621
# www.wikidata.org (labels) Q93770083|P3219|P5357|P5970|P5786|P1417...
# www.wikidata.org (labels) Q471839|Q374540|Q104144997|Q739633|Q839...
# www.wikidata.org (labels) P136|P646|P2529|P5693|P1015|P1552|P2142...
# www.wikidata.org (labels) Q8436|Q5280675|P950|Q281939|P268|P3302|...
# www.wikidata.org (labels) Q131285|P4969|P3417|Q900414|P921|P1431|...
# en.wikipedia.org (restbase) /page/summary/E.T._the_Extra-Terrestrial
# en.wikipedia.org (imageinfo) File:E t the extra terrestrial ver3....
# E.T. the Extra-Terrestrial (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> E.T., ET
#   assessments: <dict(4)> United States, Film, Science Fiction, Lib...
#   claims: <dict(117)> P1562, P57, P272, P345, P31, P161, P373, P48...
#   description: 1982 film by Steven Spielberg
#   exhtml: <str(370)> <p><i><b>E.T. the Extra-Terrestrial</b></i> i...
#   exrest: <str(349)> E.T. the Extra-Terrestrial is a 1982 American...
#   extext: <str(1629)> _**E.T. the Extra-Terrestrial**_ is a 1982 A...
#   extract: <str(1729)> <p class="mw-empty-elt"></p><p><i><b>E.T. t...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:E t the e...
#   infobox: <dict(18)> name, image, caption, director, producers, w...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:E...
#   label: E.T. the Extra-Terrestrial
#   labels: <dict(226)> Q93770083, P3219, P5357, P5970, P5786, P1417...
#   length: 94,413
#   links: <list(559)> 12 Angry Men (1957 film), 12 Monkeys, 12 Year...
#   modified: <dict(2)> page, wikidata
#   pageid: 73441
#   parsetree: <str(115831)> <root><template><title>Redirect</title>...
#   random: Talaat Dahshan
#   redirects: <list(37)> {'pageid': 177061, 'ns': 0, 'title': 'E.T....
#   requests: <list(11)> query, query, parse, wikidata, labels, labe...
#   title: E.T._the_Extra-Terrestrial
#   url: https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial
#   url_raw: <str(67)> https://en.wikipedia.org/wiki/E.T._the_Extra-...
#   watchers: 338
#   what: film
#   wikibase: Q11621
#   wikidata: <dict(117)> AllMovie title ID (P1562), director (P57),...
#   wikidata_pageid: 13150
#   wikidata_url: https://www.wikidata.org/wiki/Q11621
#   wikitext: <str(94084)> {{Redirect|E.T.|other uses|ET (disambigua...
# }

# %%
# Accessing the image attribute will return the images for this page
page.data['image']
# Out:
# [{'kind': 'parse-image',
#   'file': 'File:E t the extra terrestrial ver3.jpg',
#   'orig': 'E t the extra terrestrial ver3.jpg',
#   'timestamp': '2016-06-04T10:30:46Z',
#   'size': 83073,
#   'width': 253,
#   'height': 394,
#   'url': 'https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg',
#   'descriptionurl': 'https://en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg',
#   'descriptionshorturl': 'https://en.wikipedia.org/w/index.php?curid=7419503',
#   'title': 'File:E t the extra terrestrial ver3.jpg',
#   'metadata': {'DateTime': {'value': '2016-06-04 10:30:46',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'E t the extra terrestrial ver3',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'All non-free media|E.T. the Extra-Terrestrial|Fair use images of movie posters|Files with no machine-readable author|Noindexed pages|Wikipedia non-free files for NFUR review|Wikipedia non-free files with valid backlink',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': '', 'source': 'commons-categories', 'hidden': ''},
#    'ImageDescription': {'value': '<p>This is a poster for  <i>E.T. the Extra-Terrestrial</i>. <br>The poster art copyright is believed to belong to <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>',
#     'source': 'commons-desc-page'},
#    'Credit': {'value': '<p>The poster art can or could be obtained from <a href="//en.wikipedia.org/wiki/John_Alvin" title="John Alvin">John Alvin</a>.\n</p>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseShortName': {'value': 'Fair use',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': '<a href="//en.wikipedia.org/wiki/Wikipedia:Non-free_use_rationale_guideline" title="Wikipedia:Non-free use rationale guideline">Fair use</a> of copyrighted material in the context of <a href="//en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial" title="E.T. the Extra-Terrestrial">E.T. the Extra-Terrestrial</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Attribution': {'value': 'Source',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'LicenseUrl': {'value': '//en.wikipedia.org/wiki/File:E_t_the_extra_terrestrial_ver3.jpg',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'NonFree': {'value': 'true', 'source': 'commons-desc-page', 'hidden': ''},
#    'Copyrighted': {'value': 'True',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': '',
#     'source': 'commons-desc-page',
#     'hidden': ''}}},
#  {'file': 'File:ET logo 3.svg',
#   'kind': 'wikidata-image',
#   'orig': 'ET logo 3.svg',
#   'timestamp': '2011-05-14T20:38:17Z',
#   'size': 77290,
#   'width': 512,
#   'height': 380,
#   'url': 'https://upload.wikimedia.org/wikipedia/commons/8/85/ET_logo_3.svg',
#   'descriptionurl': 'https://commons.wikimedia.org/wiki/File:ET_logo_3.svg',
#   'descriptionshorturl': 'https://commons.wikimedia.org/w/index.php?curid=14138952',
#   'title': 'File:ET logo 3.svg',
#   'metadata': {'DateTime': {'value': '2011-05-14 20:38:17',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'ObjectName': {'value': 'ET logo 3',
#     'source': 'mediawiki-metadata',
#     'hidden': ''},
#    'CommonsMetadataExtension': {'value': 1.2,
#     'source': 'extension',
#     'hidden': ''},
#    'Categories': {'value': 'E.T. the Extra-Terrestrial|PD textlogo|SVG text logos|With trademark',
#     'source': 'commons-categories',
#     'hidden': ''},
#    'Assessments': {'value': '', 'source': 'commons-categories', 'hidden': ''},
#    'ImageDescription': {'value': 'Opening logo to the <a href="https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial" class="extiw" title="en:E.T. the Extra-Terrestrial">en:E.T. the Extra-Terrestrial</a> film',
#     'source': 'commons-desc-page'},
#    'DateTimeOriginal': {'value': '2011-02-28', 'source': 'commons-desc-page'},
#    'Credit': {'value': 'Transferred from <a class="external text" href="https://en.wikipedia.org">en.wikipedia</a>',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Artist': {'value': '<a href="https://en.wikipedia.org/wiki/en:User:TheCuriousGnome" class="extiw" title="w:en:User:TheCuriousGnome">User:TheCuriousGnome</a>',
#     'source': 'commons-desc-page'},
#    'LicenseShortName': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'UsageTerms': {'value': 'Public domain',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'AttributionRequired': {'value': 'false',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Copyrighted': {'value': 'False',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'Restrictions': {'value': 'trademarked',
#     'source': 'commons-desc-page',
#     'hidden': ''},
#    'License': {'value': 'pd', 'source': 'commons-templates', 'hidden': ''}}},
#  {'kind': 'restbase-original',
#   'width': 253,
#   'height': 394,
#   'url': 'https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg',
#   'file': 'File:E t the extra terrestrial ver3.jpg',
#   'orig': 'E_t_the_extra_terrestrial_ver3.jpg'},
#  {'kind': 'restbase-thumb',
#   'width': 205,
#   'height': 320,
#   'url': 'https://upload.wikimedia.org/wikipedia/en/thumb/6/66/E_t_the_extra_terrestrial_ver3.jpg/205px-E_t_the_extra_terrestrial_ver3.jpg',
#   'file': 'File:205px-E t the extra terrestrial ver3.jpg',
#   'orig': '205px-E_t_the_extra_terrestrial_ver3.jpg'}]
