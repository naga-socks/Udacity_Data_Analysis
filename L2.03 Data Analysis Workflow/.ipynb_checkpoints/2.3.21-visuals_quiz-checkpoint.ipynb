# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below. Remember, you created this dataset at the bottom of the notebook in the "Reading CSV Files" section earlier in the lesson! Check your work with the solutions on that page if you are having trouble getting this dataset.

# %%
# import and load data
import pandas as pd

# %matplotlib inline

df = pd.read_csv('powerplant_data_edited.csv')
df.head()
# Out:
#    Ambient Temp.  Exhaust Vacuum  Ambient Pressure  Relative Humidity  \
# 0           8.34           40.77           1010.84              90.01
# 1          23.64           58.49           1011.40              74.20
# 2          29.74           56.90           1007.15              41.91
# 3          19.07           49.69           1007.22              76.79
# 4          11.80           40.66           1017.13              97.20
#
#    Potential Energy
# 0            480.48
# 1            445.75
# 2            438.76
# 3            453.09
# 4            464.43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ambient Temp.      9568 non-null   float64
#  1   Exhaust Vacuum     9568 non-null   float64
#  2   Ambient Pressure   9568 non-null   float64
#  3   Relative Humidity  9568 non-null   float64
#  4   Potential Energy   9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# plot relationship between temperature and electrical output
df.hist(figsize=(8,8));

# %%
# plot distribution of humidity
df.plot(x='Ambient Temp.', y='Potential Energy', kind='scatter');

# %%
# plot box plots for each variable
df.plot.box(figsize=(10,10));

# %%
# compares and creates scatter plots and histogram of every 
pd.plotting.scatter_matrix(df, figsize=(15,15));

# %%
'''
the number of outliers in the dataset
there needs to be a way to mathematically determine !

Help on determining this using Z value and IQR interquartile range
https://medium.com/datadriveninvestor/finding-outliers-in-dataset-using-python-efc3fce6ce32

'''
import numpy as np
import pandas as pd
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

outlier_datapoints = detect_outlier(df.Relative_Humidity)
print(outlier_datapoints)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-74f188d6e08b> in <module>
#      15     return outliers
#      16
# ---> 17 outlier_datapoints = detect_outlier(df.Relative_Humidity)
#      18 print(outlier_datapoints)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Relative_Humidity'
